# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# for formatting
headline1 = "\n----------|"
headline2 = "|----------\n"

data = pd.read_csv('zatevon_all_games1.csv')

# heatmap of missing values (after filling)
plt.figure(figsize=(6,4))
sns.heatmap(data.isnull(), cbar=False, cmap="inferno")
plt.title("Heatmap of Missing Data After Filling")
plt.show()
# Out:
# /tmp/ipykernel_463994/3997498410.py:5: DtypeWarning: Columns (23,100,101,209) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('zatevon_all_games1.csv')

# %%
# to print datatypes
print(f"{headline1} Datatypes {headline2}{data.dtypes}")

# # of rows
print(f"{headline1} Rows {headline2}{len(data.axes[0])}")

print(f"{headline1} # of Games {headline2}{(len(data.axes[0]) - 1)/ 10}")

# # of columns
print(f"{headline1} Columns {headline2}{len(data.axes[1])}")

# of missing values
print(f"{headline1} Missing Data Count {headline2}{data.isnull().sum()}")

# for loop to go through each column and display numerical statistics or categorical statistics
for column in data.columns:
    if data[column].dtype == 'int64' or data[column].dtype == 'float64':
        print(f"{column} mean: {data[column].mean()}") # median added to .describe since it was specified in project instructions
        #print(data[column].describe())
    else:
        print(f"{headline1} {column} {headline2}")
        print(data[column].value_counts())
        print()

# %%
winrate_data = data[data['summonerName'] == 'Zatevon'][['win']]

winrate = data['win'].value_counts()

print(winrate)
# Out:
# win
# False    3771
# True     3750
# Name: count, dtype: int64
